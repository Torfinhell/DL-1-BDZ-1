# %%
import os
os.chdir("/content")
# !rm -rf DL-1-BDZ-1

# %%
# !git clone https://github.com/Torfinhell/DL-1-BDZ-1.git
os.chdir("/content/DL-1-BDZ-1")
# !git checkout 0203dbd
# Out:
# Cloning into 'DL-1-BDZ-1'...
# remote: Enumerating objects: 106, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 106 (delta 63), reused 74 (delta 31), pack-reused 0 (from 0)
# Receiving objects: 100% (106/106), 17.34 KiB | 4.33 MiB/s, done.
# Resolving deltas: 100% (63/63), done.
# Note: switching to '0203dbd'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 0203dbd Baseline 32

# %%
# !pip install -q kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter
dataset_path = kagglehub.dataset_download("nikitasolonitsyn/bdz-dl-1")
dataset_path=f"{dataset_path}/bhw1"
print("Dataset downloaded to:", dataset_path)
# !ln -s {dataset_path} ./bhw1
# Out:
# Using Colab cache for faster access to the 'bdz-dl-1' dataset.
# Dataset downloaded to: /kaggle/input/bdz-dl-1/bhw1

# %%
# !pip install \
torch==2.9.0 \
torchvision==0.24.0 \
tqdm==4.67.1 \
pandas==2.2.2 \
scikit-learn==1.6.1 \
matplotlib==3.10.0 \
seaborn==0.13.2 \
wandb==0.23.0 \
comet-ml==3.54.2 \
opencv-python==4.12.0.88
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 59.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.0/780.0 kB 58.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 64.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.3.2
#     Uninstalling python-box-7.3.2:
#       Successfully uninstalled python-box-7.3.2
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.23.1
#     Uninstalling wandb-0.23.1:
#       Successfully uninstalled wandb-0.23.1
# ...

# %%
# !pip install optuna
# !python kaggle_tuning.py #this is a script for tuning

# %%
# !python main.py --mode=train 
# --labels=/content/DL-1-BDZ-1/bhw1/labels.csv --training_dir=/content/DL-1-BDZ-1/bhw1/trainval
# Out:
# ...
# Loading classes paths: 100%|█████████████████| 200/200 [00:00<00:00, 286.81it/s]
# Traceback (most recent call last):
#   File "/home/torfinhell/Ml/DL/BDZ-1/main.py", line 218, in <module>
#     train_detector(args.labels, images_path=args.training_dir, config=config, save_model_path=args.save_model_dir)
#   File "/home/torfinhell/Ml/DL/BDZ-1/main.py", line 71, in train_detector
#     dl_train = get_dataloader(ds_train, config, "train")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/torfinhell/Ml/DL/BDZ-1/modules/training_configuration.py", line 56, in get_dataloader
#     batch_sampler=CustomBatchSampler(ds),
#                   ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/torfinhell/Ml/DL/BDZ-1/modules/training_configuration.py", line 40, in __init__
#     self.ind_to_label[i]=label
#     ~~~~~~~~~~~~~~~~~^^^
# KeyboardInterrupt
# ^C

# %%
# !python main.py --mode=predict --model_path=models/best_model.pt
